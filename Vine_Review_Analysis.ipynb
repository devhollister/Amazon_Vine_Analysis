# %%
import pandas as pd

# %%
#read in csv
df = pd.read_csv('vine_table')
df.head()
# Out:
#         review_id  star_rating  helpful_votes  total_votes vine  \
# 0   RMDCHWD0Y5OZ9          3.0            0.0          1.0    N
# 1   RZSL0BALIYUNU          5.0            0.0          0.0    N
# 2   RIZR67JKUDBI0          3.0            0.0          1.0    N
# 3  R27HL570VNL85F          5.0            0.0          0.0    N
# 4  R34EBU9QDWJ1GD          5.0            0.0          0.0    N
#
#   verified_purchase
# 0                 N
# 1                 Y
# 2                 Y
# 3                 Y
# 4                 Y

# %%
#filter df
filtered_df = df[df["total_votes"] >=20.0]
filtered_df
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 28      R2243Y3OD8U6KQ          5.0           47.0         61.0    N
# 85      R2TGT0CDTCAAHW          5.0           21.0         23.0    N
# 457      RX4D22YSXEF4P          1.0           37.0         38.0    N
# 1028    R3FL2NTLFUSPTQ          5.0           33.0         37.0    N
# 1039    R3QTP3YNZXAPPF          3.0           23.0         24.0    N
# ...                ...          ...            ...          ...  ...
# 904759  R2EJ952S3YK254          4.0           46.0         47.0    N
# 904760   R6MDTUK723YPY          4.0          143.0        148.0    N
# 904761  R10B4417NCK98O          5.0           24.0         24.0    N
# 904762  R3V2A0GUZ3JAQ4          4.0           27.0         29.0    N
# 904763  R1VYXC7FFG4LGH          4.0           46.0         49.0    N
#
#        verified_purchase
# 28                     N
# 85                     Y
# 457                    Y
# 1028                   N
# ...

# %%
#filter by helpful/total votes >= 50%
filtered_2 = filtered_df[filtered_df['helpful_votes']/filtered_df['total_votes'] >= .50] 
filtered_2
# Out:
#              review_id  star_rating  helpful_votes  total_votes vine  \
# 28      R2243Y3OD8U6KQ          5.0           47.0         61.0    N
# 85      R2TGT0CDTCAAHW          5.0           21.0         23.0    N
# 457      RX4D22YSXEF4P          1.0           37.0         38.0    N
# 1028    R3FL2NTLFUSPTQ          5.0           33.0         37.0    N
# 1039    R3QTP3YNZXAPPF          3.0           23.0         24.0    N
# ...                ...          ...            ...          ...  ...
# 904759  R2EJ952S3YK254          4.0           46.0         47.0    N
# 904760   R6MDTUK723YPY          4.0          143.0        148.0    N
# 904761  R10B4417NCK98O          5.0           24.0         24.0    N
# 904762  R3V2A0GUZ3JAQ4          4.0           27.0         29.0    N
# 904763  R1VYXC7FFG4LGH          4.0           46.0         49.0    N
#
#        verified_purchase
# 28                     N
# 85                     Y
# 457                    Y
# 1028                   N
# ...

# %%
#filter by vine program yes
paid = filtered_2[filtered_2['vine']=='Y']
paid.head()
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 4229   R1R9RU7JW0MFR2          4.0           20.0         23.0    Y
# 9120   R19EFYNN3W8Q07          5.0           26.0         32.0    Y
# 34704  R34DJ1R8AEU0SG          5.0           29.0         35.0    Y
# 38510  R25P5CXK5L9RHF          5.0          146.0        161.0    Y
# 49330  R2E9VZB3I4LSN5          5.0           55.0         59.0    Y
#
#       verified_purchase
# 4229                  N
# 9120                  N
# 34704                 N
# 38510                 N
# 49330                 N

# %%
#filter by vine program no
unpaid = filtered_2[filtered_2['vine']=='N']
unpaid.head()
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 28    R2243Y3OD8U6KQ          5.0           47.0         61.0    N
# 85    R2TGT0CDTCAAHW          5.0           21.0         23.0    N
# 457    RX4D22YSXEF4P          1.0           37.0         38.0    N
# 1028  R3FL2NTLFUSPTQ          5.0           33.0         37.0    N
# 1039  R3QTP3YNZXAPPF          3.0           23.0         24.0    N
#
#      verified_purchase
# 28                   N
# 85                   Y
# 457                  Y
# 1028                 N
# 1039                 Y

# %%
#total reviews paid
len(paid)
# Out:
# 60

# %%
#total reviews unpaid
len(unpaid)
# Out:
# 14477

# %%
# 5 star ratings paid
len(paid[paid['star_rating']==5])
# Out:
# 34

# %%
# 5 star ratings unpaid
len(unpaid[unpaid['star_rating']==5])
# Out:
# 8212

# %%
#Percent 5 star paid
len(paid[paid['star_rating']==5])/len(paid)*100
# Out:
# 56.666666666666664

# %%
# Percent 5 star unpaid
len(unpaid[unpaid['star_rating']==5])/len(unpaid)*100
# Out:
# 56.72445948746287
